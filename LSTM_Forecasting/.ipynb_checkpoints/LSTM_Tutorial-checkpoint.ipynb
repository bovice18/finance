# %%
import tensorflow as tf
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import yfinance as yf


mpl.rcParams['figure.figsize'] = (8, 6)
mpl.rcParams['axes.grid'] = False

# %%
# Get Bitcoin data
start = "2018-01-01"
end   = "2020-04-30"

df = yf.download(['BTC-USD'], 
                  start= start, 
                  end= end, 
                  progress=False)
print(df)
# Out:
#                     Open          High           Low         Close  \
# Date
# 2018-01-01  14112.200195  14112.200195  13154.700195  13657.200195
# 2018-01-02  13625.000000  15444.599609  13163.599609  14982.099609
# 2018-01-03  14978.200195  15572.799805  14844.500000  15201.000000
# 2018-01-04  15270.700195  15739.700195  14522.200195  15599.200195
# 2018-01-05  15477.200195  17705.199219  15202.799805  17429.500000
# ...                  ...           ...           ...           ...
# 2020-04-26   7570.139160   7700.594238   7561.407715   7679.867188
# 2020-04-27   7679.418945   7795.601074   7679.418945   7795.601074
# 2020-04-28   7796.970215   7814.527344   7730.806641   7807.058594
# 2020-04-29   7806.712402   8871.753906   7786.049316   8801.038086
# 2020-04-30   8797.669922   9440.650391   8533.255859   8658.553711
#
#                Adj Close       Volume
# Date
# 2018-01-01  13657.200195  10291200000
# 2018-01-02  14982.099609  16846600192
# 2018-01-03  15201.000000  16871900160
# 2018-01-04  15599.200195  21783199744
# 2018-01-05  17429.500000  23840899072
# ...                  ...          ...
# 2020-04-26   7679.867188  33070154490
# 2020-04-27   7795.601074  36162144724
# 2020-04-28   7807.058594  33187959920
# 2020-04-29   8801.038086  60201052202
# 2020-04-30   8658.553711  66964629541
#
# [851 rows x 6 columns]

# %%
# Plot daily prices of Bitcoin
df['Close'].plot()

# %%
def univariate_data(dataset, start_index, end_index, history_size, target_size):
    data = []
    labels = []

    start_index = start_index + history_size
    if end_index is None:
        end_index = len(dataset) - target_size

    for i in range(start_index, end_index):
        indices = range(i-history_size, i)
        # Reshape data from (history_size,) to (history_size, 1)
        data.append(np.reshape(dataset[indices], (history_size, 1)))
        labels.append(dataset[i+target_size])
    return np.array(data), np.array(labels)

# %%
# 851 rows of data for 1/1/2018 - 4/30/2020
# use 650 training days
TRAIN_SPLIT = 700

# %%
tf.random.set_seed(13)

# %%
# Use a univariate set to try to predict prices
uni_data = df['Close']

# Scale the data
uni_data = (uni_data-uni_data.mean())/uni_data.std()
uni_data = uni_data.values

# %%
len(uni_data)
# Out:
# 851

# %%
univariate_past_history = 20
univariate_future_target = 0

x_train_uni, y_train_uni = univariate_data(uni_data, 0, TRAIN_SPLIT,
                                           univariate_past_history,
                                           univariate_future_target)
x_val_uni, y_val_uni = univariate_data(uni_data, TRAIN_SPLIT, None,
                                       univariate_past_history,
                                       univariate_future_target)

# %%
print(len(x_train_uni))
print(len(x_val_uni))
# Out:
# 680
# 131

# %%
print ('Single window of past history')
print (x_train_uni[0])
print ('\n Target temperature to predict')
print (y_train_uni[0])
# Out:
# Single window of past history
# [[2.51783734]
#  [3.06481595]
#  [3.15518796]
#  [3.31958307]
#  [4.07521389]
#  [4.11546631]
#  [3.68222621]
#  [3.14243088]
#  [2.90516896]
#  [3.06118299]
#  [2.41404785]
#  [2.6513513 ]
#  [2.80806765]
#  [2.56523191]
#  [2.58496584]
#  [1.62332518]
#  [1.498687  ]
#  [1.61688495]
#  [1.67158697]
#  [2.20490055]]
#
#  Target temperature to predict
# 1.6685728720641269

# %%
def create_time_steps(length):
    return list(range(-length, 0))

# %%
def show_plot(plot_data, delta, title):
    labels = ['History', 'True Future', 'Model Prediction']
    marker = ['.-', 'rx', 'go']
    time_steps = create_time_steps(plot_data[0].shape[0])
    if delta:
        future = delta
    else:
        future = 0

    plt.title(title)
    for i, x in enumerate(plot_data):
        if i:
            plt.plot(future, plot_data[i], marker[i], markersize=10,
                   label=labels[i])
        else:
            plt.plot(time_steps, plot_data[i].flatten(), marker[i], label=labels[i])
    plt.legend()
    plt.xlim([time_steps[0], (future+5)*2])
    plt.xlabel('Time-Step')
    return plt

# %%
show_plot([x_train_uni[0], y_train_uni[0]], 0, 'Sample Prediction Task')
# Out:
# <module 'matplotlib.pyplot' from '/home/bwood/miniconda3/envs/finance/lib/python3.7/site-packages/matplotlib/pyplot.py'>

# %%
baseline = np.mean(x_train_uni[0])
show_plot([x_train_uni[0], y_train_uni[0], baseline], 0,
           'Baseline (Mean) Prediction Example')
# Out:
# <module 'matplotlib.pyplot' from '/home/bwood/miniconda3/envs/finance/lib/python3.7/site-packages/matplotlib/pyplot.py'>

# %%
### Create Recurrent Neural Net

# Setup data for the RNN model
BATCH_SIZE = 20
BUFFER_SIZE = 10000

# Training Data
train_univariate = tf.data.Dataset.from_tensor_slices((x_train_uni, y_train_uni))
train_univariate = train_univariate.cache().shuffle(BUFFER_SIZE).batch(BATCH_SIZE).repeat()

# Test Data
val_univariate = tf.data.Dataset.from_tensor_slices((x_val_uni, y_val_uni))
val_univariate = val_univariate.batch(BATCH_SIZE).repeat()


# Setup model
simple_lstm_model = tf.keras.models.Sequential([
    tf.keras.layers.LSTM(8, input_shape=x_train_uni.shape[-2:]),
    tf.keras.layers.Dense(1)
])

simple_lstm_model.compile(optimizer='adam', loss='mae')

# %%
# Train Model
EVALUATION_INTERVAL = 200
EPOCHS = 10

simple_lstm_model.fit(train_univariate, epochs=EPOCHS,
                      steps_per_epoch=EVALUATION_INTERVAL,
                      validation_data=val_univariate, validation_steps=50)
# Out:
# Epoch 1/10
# 200/200 [==============================] - 2s 9ms/step - loss: 0.4131 - val_loss: 0.1840
# Epoch 2/10
# 200/200 [==============================] - 1s 7ms/step - loss: 0.1615 - val_loss: 0.1523
# Epoch 3/10
# 200/200 [==============================] - 1s 7ms/step - loss: 0.1294 - val_loss: 0.1357
# Epoch 4/10
# 200/200 [==============================] - 1s 7ms/step - loss: 0.1144 - val_loss: 0.1244
# Epoch 5/10
# 200/200 [==============================] - 1s 7ms/step - loss: 0.1059 - val_loss: 0.1117
# Epoch 6/10
# 200/200 [==============================] - 1s 7ms/step - loss: 0.0994 - val_loss: 0.1066
# Epoch 7/10
# 200/200 [==============================] - 1s 7ms/step - loss: 0.0945 - val_loss: 0.0989
# Epoch 8/10
# 200/200 [==============================] - 1s 7ms/step - loss: 0.0911 - val_loss: 0.0940
# Epoch 9/10
# 200/200 [==============================] - 1s 7ms/step - loss: 0.0895 - val_loss: 0.0909
# Epoch 10/10
# 200/200 [==============================] - 1s 7ms/step - loss: 0.0869 - val_loss: 0.0901

# %%
# Show 3 model predictions using the test data
for x, y in val_univariate.take(3):
    plot = show_plot([x[0].numpy(), y[0].numpy(),
                     simple_lstm_model.predict(x)[0]], 0, 'Simple LSTM model')
    plot.show()

# %% [markdown]
# # Use Multivariate Data Now

# %%
df.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
features_considered = ['Close', 'Open', 'High', 'Low', 'Volume']
features = df[features_considered]
features.head()
# Out:
#                    Close          Open          High           Low  \
# Date
# 2018-01-01  13657.200195  14112.200195  14112.200195  13154.700195
# 2018-01-02  14982.099609  13625.000000  15444.599609  13163.599609
# 2018-01-03  15201.000000  14978.200195  15572.799805  14844.500000
# 2018-01-04  15599.200195  15270.700195  15739.700195  14522.200195
# 2018-01-05  17429.500000  15477.200195  17705.199219  15202.799805
#
#                  Volume
# Date
# 2018-01-01  10291200000
# 2018-01-02  16846600192
# 2018-01-03  16871900160
# 2018-01-04  21783199744
# 2018-01-05  23840899072

# %%
features.plot(subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f45d0241050>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f4598640250>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f4598655050>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f45984dc5d0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f459848e9d0>],
#       dtype=object)

# %%
dataset = features.values
data_mean = dataset[:TRAIN_SPLIT].mean(axis=0)
data_std = dataset[:TRAIN_SPLIT].std(axis=0)
dataset = (dataset-data_mean)/data_std

# %% [markdown]
# ## Single Step Prediction

# %%
def multivariate_data(dataset, target, start_index, end_index, history_size,
                      target_size, step, single_step=False):
    data = []
    labels = []

    start_index = start_index + history_size
    if end_index is None:
        end_index = len(dataset) - target_size

    for i in range(start_index, end_index):
        indices = range(i-history_size, i, step)
        data.append(dataset[indices])

        if single_step:
            labels.append(target[i+target_size])
        else:
            labels.append(target[i:i+target_size])

    return np.array(data), np.array(labels)

# %%
past_history = 20
future_target = 1
STEP = 1

x_train_single, y_train_single = multivariate_data(dataset, dataset[:, 0], 0,
                                                   TRAIN_SPLIT, past_history,
                                                   future_target, STEP,
                                                   single_step=True)
x_val_single, y_val_single = multivariate_data(dataset, dataset[:, 0],
                                               TRAIN_SPLIT, None, past_history,
                                               future_target, STEP,
                                               single_step=True)

# %%
print ('Single window of past history : {}'.format(x_train_single[0].shape))
# Out:
# Single window of past history : (20, 5)

# %%
# Setup data for RNN model
# Training
train_data_single = tf.data.Dataset.from_tensor_slices((x_train_single, y_train_single))
train_data_single = train_data_single.cache().shuffle(BUFFER_SIZE).batch(BATCH_SIZE).repeat()
# Testing
val_data_single = tf.data.Dataset.from_tensor_slices((x_val_single, y_val_single))
val_data_single = val_data_single.batch(BATCH_SIZE).repeat()

# Model Architecture
single_step_model = tf.keras.models.Sequential()
single_step_model.add(tf.keras.layers.LSTM(32, input_shape=x_train_single.shape[-2:]))
single_step_model.add(tf.keras.layers.Dense(1))
single_step_model.compile(optimizer=tf.keras.optimizers.RMSprop(), loss='mae')

# %%
# Train RNN Model
single_step_history = single_step_model.fit(train_data_single, epochs=EPOCHS,
                                            steps_per_epoch=EVALUATION_INTERVAL,
                                            validation_data=val_data_single,
                                            validation_steps=50)
# Out:
# Epoch 1/10
# 195/200 [============================>.] - ETA: 0s - loss: 0.2123

# %%
def plot_train_history(history, title):
    loss = history.history['loss']
    val_loss = history.history['val_loss']

    epochs = range(len(loss))

    plt.figure()

    plt.plot(epochs, loss, 'b', label='Training loss')
    plt.plot(epochs, val_loss, 'r', label='Validation loss')
    plt.title(title)
    plt.legend()

    plt.show()

# %%
plot_train_history(single_step_history,
                   'Single Step Training and validation loss')

# %%
for x, y in val_data_single.take(3):
    plot = show_plot([x[0][:, 1].numpy(), y[0].numpy(),
                    single_step_model.predict(x)[0]], 1,
                   'Single Step Prediction')
    plot.show()

# %% [markdown]
# ## Multi-Step Prediction

# %%
future_target = 10
x_train_multi, y_train_multi = multivariate_data(dataset, dataset[:, 0], 0,
                                                 TRAIN_SPLIT, past_history,
                                                 future_target, STEP)
x_val_multi, y_val_multi = multivariate_data(dataset, dataset[:, 0],
                                             TRAIN_SPLIT, None, past_history,
                                             future_target, STEP)

# %%
print ('Single window of past history : {}'.format(x_train_multi[0].shape))
print ('\n Target temperature to predict : {}'.format(y_train_multi[0].shape))

# %%
train_data_multi = tf.data.Dataset.from_tensor_slices((x_train_multi, y_train_multi))
train_data_multi = train_data_multi.cache().shuffle(BUFFER_SIZE).batch(BATCH_SIZE).repeat()

val_data_multi = tf.data.Dataset.from_tensor_slices((x_val_multi, y_val_multi))
val_data_multi = val_data_multi.batch(BATCH_SIZE).repeat()

# %%
def multi_step_plot(history, true_future, prediction):
    plt.figure(figsize=(12, 6))
    num_in = create_time_steps(len(history))
    num_out = len(true_future)

    plt.plot(num_in, np.array(history[:, 1]), label='History')
    plt.plot(np.arange(num_out)/STEP, np.array(true_future), 'bo',
           label='True Future')
    if prediction.any():
        plt.plot(np.arange(num_out)/STEP, np.array(prediction), 'ro',
                 label='Predicted Future')
    plt.legend(loc='upper left')
    plt.show()

# %%
for x, y in train_data_multi.take(1):
    multi_step_plot(x[0], y[0], np.array([0]))

# %%
# Model Architecture
    multi_step_model = tf.keras.models.Sequential()
    multi_step_model.add(tf.keras.layers.LSTM(32,
                                              return_sequences=True,
                                              input_shape=x_train_multi.shape[-2:]))
    multi_step_model.add(tf.keras.layers.LSTM(16, activation='relu'))
    multi_step_model.add(tf.keras.layers.Dense(10))

    multi_step_model.compile(optimizer=tf.keras.optimizers.RMSprop(clipvalue=1.0), loss='mae')

# %%
x_train_multi.shape[-2:]

# %%
multi_step_history = multi_step_model.fit(train_data_multi, epochs=EPOCHS,
                                          steps_per_epoch=EVALUATION_INTERVAL,
                                          validation_data=val_data_multi,
                                          validation_steps=50)

# %%
plot_train_history(multi_step_history, 'Multi-Step Training and validation loss')

# %%
for x, y in val_data_multi.take(3):
    multi_step_plot(x[0], y[0], multi_step_model.predict(x)[0])
